# %% [markdown]
# ### Master oficial en Big Data & Data Science - Universidad Internacional de Valencia (VIU)

# %% [markdown]
# <font color="darkblue">
#
# -   **Alumno:** Franco Rojas Yucra
# -   **TFM:** Sistema para la busqueda de conocimientos en textos de documentos multimedia
# -   **Email:** franco.rojasyucra@alumnos.viu.es
# -   **Fecha:** Octubre de 2023
# <font color="black">

# %% [markdown]
# ## 07 Entrenamiento de modelo Falcon-rw-1B con fine tuning

# %% [markdown]
# Librerías generales

# %%
import pandas as pd
import numpy as np
import os
import random
import math
from IPython.display import display, HTML

# %%
pd.set_option('display.max_columns',None) #motrar todas las columnas

# %% [markdown]
# Estableciendo directorio trabajo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print('Ruta actual: '+os.getcwd())
os.chdir('/content/drive/MyDrive/TFM_VIU_Franco_Rojas')
print('Ruta donde se almacenaran archivos: '+os.getcwd())
# Out:
# Ruta actual: /content
# Ruta donde se almacenaran archivos: /content/drive/MyDrive/TFM_VIU_Franco_Rojas

# %% [markdown]
# ### Configuraciones iniciales para trabajar con LLM

# %% [markdown]
# Intalación de librerias para LLM

# %%
# !pip install -q huggingface_hub datasets evaluate transformers[torch] accelerate -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 5.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 33.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.4/81.4 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 82.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.1/258.1 kB 32.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 108.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 78.5 MB/s eta 0:00:00

# %%
# !apt install git-lfs
# !git config --global user.email "franco.rojas.yucra@gmail.com"
# !git config --global user.name "franco-rojas"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# git-lfs is already the newest version (3.0.2-1ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 18 not upgraded.

# %% [markdown]
# Importando librerías para LLM

# %%
from datasets import load_dataset
from datasets import ClassLabel
from transformers import AutoTokenizer
from transformers import AutoModelForCausalLM
from transformers import Trainer, TrainingArguments
import accelerate

# %% [markdown]
# Loguearse con cuenta de Hugging Face para carga de modelos LLM
# ##### Cuenta logueada: https://huggingface.co/franco-rojas

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ### Lectura de dataset y preparación para entrenamiento

# %% [markdown]
# Dataset de transcripciones despues de limpieza

# %%
df_transcrip=pd.read_csv('transformed_corpus/conjunto_transcripciones_fin.csv',sep='|')

# %%
df_transcrip.head()
# Out:
#     id_doc                   tema  \
# 0  DOC0001  Internet de las cosas
# 1  DOC0002  Internet de las cosas
# 2  DOC0003        Introduccion IA
# 3  DOC0004        Introduccion IA
# 4  DOC0005        Introduccion IA
#
#                                  transcription_filt2
# 0  Bienvenidos a nuestro canal de YouTube, Intern...
# 1  Bienvenidos al curso Internet de las Cosas. Mi...
# 2  Hola a todos y bienvenidos a un nuevo video en...
# 3  Hola a todos y bienvenidos a un nuevo video en...
# 4  Hola a todos y bienvenidos a un nuevo video en...

# %% [markdown]
# Lectura de dataset con librería datasets

# %%
dataset = load_dataset('csv', data_files=['transformed_corpus/conjunto_transcripciones_fin.csv'],delimiter="|", split='train')
# Out:
# Downloading data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting data files:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['id_doc', 'tema', 'transcription_filt2'],
#     num_rows: 147
# })

# %% [markdown]
# Separación de documentos: 80% (entrenamiento) y 20% (validación)

# %%
datasets = dataset.train_test_split(test_size=0.20)

# %%
datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id_doc', 'tema', 'transcription_filt2'],
#         num_rows: 117
#     })
#     test: Dataset({
#         features: ['id_doc', 'tema', 'transcription_filt2'],
#         num_rows: 30
#     })
# })

# %% [markdown]
# Modelo a utilizar

# %%
model_checkpoint = "tiiuae/falcon-rw-1b"

# %% [markdown]
# Descargando tokenizador de modelo original

# %%
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, use_fast=True)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]

# %% [markdown]
# Tokenización de documentos de acuerdo a modelo original

# %%
def tokenize_fn(examples):
    return tokenizer(examples["transcription_filt2"])

# %%
df_transcrip.columns
# Out:
# Index(['id_doc', 'tema', 'transcription_filt2'], dtype='object')

# %%
tokenized_datasets = datasets.map(tokenize_fn, batched=True, remove_columns=["id_doc","tema","transcription_filt2"])
# Out:
# Map:   0%|          | 0/117 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (3023 > 1024). Running this sequence through the model will result in indexing errors
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]

# %%
#La columna con los valores tokenizados y transformados a numerico es "input_ids"
#los valores para la matriz de atención es "attention_mask"
tokenized_datasets.column_names
# Out:
# {'train': ['input_ids', 'attention_mask'],
#  'test': ['input_ids', 'attention_mask']}

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 117
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask'],
#         num_rows: 30
#     })
# })

# %% [markdown]
# Transformación de dataset para entrenamiento

# %%
#block_size = tokenizer.model_max_length
block_size = 128

# %%
#Función para agrupar textos y definir labels a predecir
def group_texts(examples):
    # Concatenate all texts.
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    total_length = (total_length // block_size) * block_size
    result = {
        k: [t[i : i + block_size] for i in range(0, total_length, block_size)]
        for k, t in concatenated_examples.items()
    }
    result["labels"] = result["input_ids"].copy()
    return result

# %%
lm_datasets = tokenized_datasets.map(group_texts,batched=True,batch_size=1000)
# Out:
# Map:   0%|          | 0/117 [00:00<?, ? examples/s]
# Map:   0%|          | 0/30 [00:00<?, ? examples/s]

# %%
lm_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 3239
#     })
#     test: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 747
#     })
# })

# %% [markdown]
# ### Entrenamiento de modelo

# %% [markdown]
# Descargando modelo original desde Hugging Face

# %%
model = AutoModelForCausalLM.from_pretrained(model_checkpoint)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.05k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/2.62G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/115 [00:00<?, ?B/s]

# %% [markdown]
# Parametros de entrenamiento

# %%
training_args = TrainingArguments(
    "finetuned_models",
    #per_device_train_batch_size = 2,
    #per_device_eval_batch_size = 2,
    evaluation_strategy = "epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    push_to_hub=True,
    push_to_hub_model_id=f"falcon-rw-1b-finetuned-tfmviu"
)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/training_args.py:1696: FutureWarning: `--push_to_hub_model_id` is deprecated and will be removed in version 5 of 🤗 Transformers. Use `--hub_model_id` instead and pass the full repo name to this argument (in this case franco-rojas/falcon-rw-1b-finetuned-tfmviu).
#   warnings.warn(

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=lm_datasets["train"],
    eval_dataset=lm_datasets["test"],
)

# %% [markdown]
# Metrica Perplejidad previo a entrenamiento

# %%
### BORRAR
evaluate_prev=trainer.evaluate()
print(f"Perplexity: {math.exp(evaluate_prev['eval_loss']):.2f}")
# Out:
#     <div>
#
#       <progress value='94' max='94' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [94/94 00:16]
#     </div>
# Perplexity: 16.49

# %% [markdown]
# Entrenamiento del modelo

# %%
# %%time
trainer.train()
# Out:
#     <div>
#
#       <progress value='1215' max='1215' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1215/1215 15:04, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>2.382560</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.321700</td>
#       <td>2.363328</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.405300</td>
#       <td>2.595799</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='188' max='94' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [94/94 04:56]
#     </div>
# CPU times: user 11min 54s, sys: 2min 36s, total: 14min 30s
# Wall time: 16min 21s
# TrainOutput(global_step=1215, training_loss=1.6980311264226466, metrics={'train_runtime': 905.6112, 'train_samples_per_second': 10.73, 'train_steps_per_second': 1.342, 'total_flos': 9019385623609344.0, 'train_loss': 1.6980311264226466, 'epoch': 3.0})

# %% [markdown]
# Metrica Perplejidad para muestra de evaluación

# %%
eval_results = trainer.evaluate()
print(f"Perplexity: {math.exp(eval_results['eval_loss']):.2f}")
# Out:
#     <div>
#
#       <progress value='94' max='94' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [94/94 00:16]
#     </div>
# Perplexity: 13.41

# %% [markdown]
# #### Carga final de modelo y tokenizador a Hugging Face

# %%
trainer.push_to_hub()
# Out:
# pytorch_model.bin:   0%|          | 0.00/5.25G [00:00<?, ?B/s]
# 'https://huggingface.co/franco-rojas/falcon-rw-1b-finetuned-tfmviu/tree/main/'

# %%
tokenizer.push_to_hub('falcon-rw-1b-finetuned-tfmviu')
# Out:
# CommitInfo(commit_url='https://huggingface.co/franco-rojas/falcon-rw-1b-finetuned-tfmviu/commit/dc2e3343c357ddbbd68a3d5532c0ab6aae73ccc8', commit_message='Upload tokenizer', commit_description='', oid='dc2e3343c357ddbbd68a3d5532c0ab6aae73ccc8', pr_url=None, pr_revision=None, pr_num=None)
